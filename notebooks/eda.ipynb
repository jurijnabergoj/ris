# %%
import numpy as np
from PIL import Image
from matplotlib import pyplot as plt
import pandas as pd
import os

# %%
import os
os.getcwd()

# %%
sample_image = Image.open("/data/ris2026-krog1-ucni/1a8211e8.png")

plt.imshow(sample_image)
plt.show()

print(np.array(sample_image).shape)

# %%
labels = pd.read_csv("/data/ucni_set.csv")
labels

# %%
unique_labels = labels.unique()
